# %%
from Haptik import Haptik
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
path = '~/Downloads/haptik_open_datasets-master/domain_classification'
x = Haptik(path)
x.wordcloud()
# Out:
# Haptik.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.y_train[colname] = self.y_train[colname].astype(str).map({'F':0, 'T':1})
# Haptik.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.y_test[colname] = self.y_test[colname].astype(str).map({'F':0, 'T':1})
# 'wordcloud'  17413.65 ms
# <Haptik.Haptik instance at 0x7f54f2964680>

# %%
tokenizer = RegexpTokenizer(r'\w+')
vect = TfidfVectorizer(stop_words = 'english', ngram_range = (1,3),
        tokenizer = tokenizer.tokenize, min_df = 1, max_df = 0.70, norm = 'l1',
        max_features = 25000, sublinear_tf = True)
model = MultinomialNB(alpha=0.25, class_prior=None, fit_prior=False)
x.classify(vect = vect, model = model)
# Out:
# 'classify'  2780.46 ms
# 0.80220000000000002
